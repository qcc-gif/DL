# %% [markdown]
# <a href="https://colab.research.google.com/github/qcc-gif/DL/blob/main/DriveToDeepLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/.git/

# %%
# !git add .

# %%
# !git commit -m "First commit"
# Out:
# [master (root-commit) a41796d] First commit
#  407 files changed, 272637 insertions(+)
#  create mode 100644 D2L
#  create mode 100644 DriveToDeepLearning.ipynb
#  create mode 100644 Untitled0.ipynb
#  create mode 100644 Untitled1.ipynb
#  create mode 100644 pytorch/.DS_Store
#  create mode 100644 pytorch/TERMINOLOGY.ipynb
#  create mode 100644 pytorch/chapter_appendix-tools-for-deep-learning/aws.ipynb
#  create mode 100644 pytorch/chapter_appendix-tools-for-deep-learning/contributing.ipynb
#  create mode 100644 pytorch/chapter_appendix-tools-for-deep-learning/d2l.ipynb
#  create mode 100644 pytorch/chapter_appendix-tools-for-deep-learning/index.ipynb
#  create mode 100644 pytorch/chapter_appendix-tools-for-deep-learning/jupyter.ipynb
#  create mode 100644 pytorch/chapter_appendix-tools-for-deep-learning/sagemaker.ipynb
#  create mode 100644 pytorch/chapter_appendix-tools-for-deep-learning/selecting-servers-gpus.ipynb
# ...

# %%
# !git config --global user.email "1633752749@qq.com"
# !git config --global user.name "qcc-gif"

# %%
# !git remote add bratch https://github.com/qcc-gif/DL.git
# Out:
# error: remote bratch already exists.

# %%
# !git push -u bratch master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
